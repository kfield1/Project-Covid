# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#set working directory
#os.chdir("Jan to Feb 2021")

# %%
#find all csv files in the folder 
#use glob pattern matching -> extension = 'csv'
#save result in list ->all_filenames

os.chdir("Oct to Dec 2020")
extension = 'csv'
all_filesnames20 = ["Oct to Dec 2020/"+i for i in glob.glob('*.{}'.format(extension))]

all_filesnames20
# Out:
# ['Oct to Dec 2020/10-05-2020.csv',
#  'Oct to Dec 2020/10-12-2020.csv',
#  'Oct to Dec 2020/10-19-2020.csv',
#  'Oct to Dec 2020/10-26-2020.csv',
#  'Oct to Dec 2020/11-02-2020.csv',
#  'Oct to Dec 2020/11-09-2020.csv',
#  'Oct to Dec 2020/11-16-2020.csv',
#  'Oct to Dec 2020/11-23-2020.csv',
#  'Oct to Dec 2020/11-30-2020.csv',
#  'Oct to Dec 2020/12-07-2020.csv',
#  'Oct to Dec 2020/12-14-2020.csv',
#  'Oct to Dec 2020/12-21-2020.csv',
#  'Oct to Dec 2020/12-28-2020.csv']

# %%
os.chdir("../Jan to Feb 2021")
extension = 'csv'
all_filesnames21 = ["Jan to Feb 2021/"+i for i in glob.glob('*.{}'.format(extension))]

os.chdir("..")

all_filesnames21
# Out:
# ['Jan to Feb 2021/01-04-2021.csv',
#  'Jan to Feb 2021/01-11-2021.csv',
#  'Jan to Feb 2021/01-18-2021.csv',
#  'Jan to Feb 2021/01-25-2021.csv',
#  'Jan to Feb 2021/02-01-2021.csv',
#  'Jan to Feb 2021/02-08-2021.csv',
#  'Jan to Feb 2021/02-15-2021.csv',
#  'Jan to Feb 2021/02-22-2021.csv']

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filesnames20+all_filesnames21])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

us_cases_csv=(combined_csv.to_csv)

# %%
#all_filesnames20+all_filesnames21

# %%
us_cases_df = pd.read_csv("combined_csv.csv")
us_cases_df.head ()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2020-10-06 04:30:27  32.3182  -86.9023
# 1          Alaska             US  2020-10-06 04:30:27  61.3707 -152.4044
# 2  American Samoa             US  2020-10-06 04:30:27 -14.2710 -170.1320
# 3         Arizona             US  2020-10-06 04:30:27  33.7298 -111.4312
# 4        Arkansas             US  2020-10-06 04:30:27  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered    Active  FIPS  Incident_Rate  People_Tested  \
# 0     159476    2559    67948.0   89206.0   1.0    3257.331714      1167513.0
# 1       8613      58     5455.0    3100.0   2.0    1177.371180       479374.0
# 2          0       0        NaN       0.0  60.0       0.000000         1616.0
# 3     221070    5707    36007.0  179356.0   4.0    3037.211091      1502873.0
# 4      87430    1447    79052.0    6931.0   5.0    2897.139774      1079144.0
#
# ...

# %%
us_cases_df.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3',
#        'Testing_Rate', 'Hospitalization_Rate', 'Total_Test_Results',
#        'Case_Fatality_Ratio'],
#       dtype='object')

# %%
organized_data_df= us_cases_df [["Province_State","Last_Update","Confirmed","Deaths","Recovered","Active"]]
organized_data_df.head(70)
# Out:
#           Province_State          Last_Update  Confirmed  Deaths  Recovered  \
# 0                Alabama  2020-10-06 04:30:27     159476    2559    67948.0
# 1                 Alaska  2020-10-06 04:30:27       8613      58     5455.0
# 2         American Samoa  2020-10-06 04:30:27          0       0        NaN
# 3                Arizona  2020-10-06 04:30:27     221070    5707    36007.0
dec_29_df=organized_data_df[(organized_data_df["Last_Update"]=="2020-12-29 05:30:33")] 
dec_29_df
# Out:
#                Province_State          Last_Update  Confirmed  Deaths  \
# 696                   Alabama  2020-12-29 05:30:33     347897    4712
# 697                    Alaska  2020-12-29 05:30:33      45909     200
# 698            American Samoa  2020-12-29 05:30:33          0       0
# 699                   Arizona  2020-12-29 05:30:33     504423    8469
# 700                  Arkansas  2020-12-29 05:30:33     216528    3537
# 701                California  2020-12-29 05:30:33    2222669   24546
# 702                  Colorado  2020-12-29 05:30:33     326668    4631
# 703               Connecticut  2020-12-29 05:30:33     181200    5904
# 704                  Delaware  2020-12-29 05:30:33      55488    1041
# 705          Diamond Princess  2020-12-29 05:30:33         49       0
# 706      District of Columbia  2020-12-29 05:30:33      28342     771
# 707                   Florida  2020-12-29 05:30:33    1280177   21308
# ...

# %%
#states = {}
#organized_data_df_ir = organized_data_df.iterrows()
#for index, row in organized_data_df_ir:
#    s = row['Province_State']
#   l = row['Last_Update']
#     if s not in states:
#         states[s] = {
#             'Confirmed' : 0,
#             'Deaths' : 0,
#             'Recovered' : 0,
#             'Active' : 0,
#             'People_Tested' : 0      
#         }
#     else:
#         states[s]['Confirmed'] += float(row['Confirmed'])
#         states[s]['Deaths'] += float(row['Deaths'])
#         states[s]['Recovered'] += float(row['Recovered'])
#         states[s]['Active'] += float(row['Active'])
#         states[s]['People_Tested'] += float(row['People_Tested'])
#     if (int(l.split(' ')[0][-2:]) > 6):
#         break

# dated_states = {}
# dated_states[l] = states
# dated_states
# #start with 7
# states[row['Pr']]

# for index, row in organized_data_df_ir:
#     s = row['Province_State']
#     l = row['Last_Update']
#     if s not in states:
#         states[s] = {
#             'Confirmed' : 0,
#             'Deaths' : 0,
#             'Recovered' : 0,
#             'Active' : 0,
#             'People_Tested' : 0      
#         }
#     else:
#         states[s]['Confirmed'] += float(row['Confirmed'])
#         states[s]['Deaths'] += float(row['Deaths'])
#         states[s]['Recovered'] += float(row['Recovered'])
#         states[s]['Active'] += float(row['Active'])
#         states[s]['People_Tested'] += float(row['People_Tested'])
#     if

# %%
x_axis = np.arrange(len(oct_27_df))
tick_locations = [value for value in x_axis]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-3e3a22edcf5a> in <module>
# ----> 1 x_axis = np.arrange(len(oct_27_df))
#       2 tick_locations = [value for value in x_axis]
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     212                 return Tester
#     213             else:
# --> 214                 raise AttributeError("module {!r} has no attribute "
#     215                                      "{!r}".format(__name__, attr))
#     216
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
#renamed_data_df= organized_data_df.rename(columns=("State":"Province_State","Updated":"Last_Update"))
# Out:
#   File "<ipython-input-18-bd136e491477>", line 1
#     renamed_data_df= organized_data_df.rename(columns=("State":"Province_State","Updated":"Last_Update"))
#                                                               ^
# SyntaxError: invalid syntax

# %%
#no_null_us_cases_df = us_cases_df.dropna(how='any')
no_null_us_cases_df.head()
# Out:
# Empty DataFrame
# Columns: [Province_State, Country_Region, Last_Update, Lat, Long_, Confirmed, Deaths, Recovered, Active, FIPS, Incident_Rate, People_Tested, People_Hospitalized, Mortality_Rate, UID, ISO3, Testing_Rate, Hospitalization_Rate, Total_Test_Results, Case_Fatality_Ratio]
# Index: []

# %%
#no_null_us_cases_df.groupby()
